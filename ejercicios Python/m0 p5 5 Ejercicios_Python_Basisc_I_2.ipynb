# %% [markdown]
# ![TheBridge_logo_RGB_color.jpg](attachment:TheBridge_logo_RGB_color.jpg)

# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# ## EJERCICIOS PYTHON BASICO 2:
# ## Tipos y conversión de tipos

# %% [markdown]
# Completa los siguiente ejercicios, la solución a los mismos se publicarán en el repo del curso a lo largo del sprint

# %% [markdown]
# ![ejercicio.png](./img/ejercicio.png)
#
# ## Ejercicio 1
#
# 1. Crea dos variables numericas: un `int` y un `float`
# 2. Comprueba sus tipos
# 3. Sumalas en otra nueva
# 4. ¿De qué tipo es la nueva variable?
# 5. Elimina las dos primeras variables creadas

# %%
var1 = 7 #int
var2 = 3.1416 #float
print("\nLa varible var1 es del tipo",type(var1), "Y su valor es", var1)
print("\nLa varible var1 es del tipo",type(var2), "Y su valor es", var2)
var3 = var1 + var2
print("\nLa varible var3 es del tipo",type(var3), "Y su valor es", var3, "que se corresponde con la suma de las anteriores.")

del var1,var2
print("\nEliminadas las dos primeras variables creadas.")
# Out:
# La varible var1 es del tipo <class 'int'> Y su valor es 7
#
# La varible var1 es del tipo <class 'float'> Y su valor es 3.1416
#
# La varible var3 es del tipo <class 'float'> Y su valor es 10.1416 que se corresponde con la suma de las anteriores.
#
# Eliminadas las dos primeras variables creadas.

# %% [markdown]
# ![ejercicio.png](./img/ejercicio.png)
#
# ## Ejercicio 2
# Escribe un programa para pasar de grados a radianes. Hay que usar `input`. Recuerda que la conversión se realiza mediante
#
# radianes = grados*(pi/180)

# %%
print("\nPrograma para pasar de Grados a Radianes.")
grados = float(input("\nIntroduce los Grados:").replace(",","."))
pi = 3.1416
radianes = grados*(pi/180)
print("\nRadianes = Grados*(Pi/180)\n",grados,"Grados corresponden a", radianes, "Radianes")
# Out:
# Programa para pasar de Grados a Radianes.
# Introduce los Grados: 7,9999
# Radianes = Grados*(Pi/180)
#  7.9999 Grados corresponden a 0.13962492133333335 Radianes

# %% [markdown]
# ![ejercicio.png](./img/ejercicio.png)
#
# ## Ejercicio 3
# Escribe un programa que calcule el area de un paralelogramo (base x altura). También con `input`

# %%
print("\nPrograma para calcular el area de un paralelogramo (base x altura).")
base = float(input("\n Introduce la base:").replace(",","."))
altura = float(input("\n Introduce la altura:").replace(",","."))
print("\nEl área del paralelogramo es", base*altura, "unidades cuadradas." )
# Out:
# Programa para calcular el area de un paralelogramo (base x altura).
#  Introduce la base: 7,8
#
#  Introduce la altura: 8,7
# El área del paralelogramo es 67.86 unidades cuadradas.

# %% [markdown]
# ![ejercicio.png](./img/ejercicio.png)
#
# ## Ejercicio 4
# Escribe un programa que calcule el area de un paralelogramo (base x altura). También con `input`. En este caso debe ser capaz de admitir valores reales, con decimales, para base y altura en español. (PISTA: Recuerda que tendrás que hacer uso del método replace)

# %%
print("\nPrograma para calcular el area de un paralelogramo (base x altura).")
base = float(input("\n Introduce la base:").replace(",","."))
altura = float(input("\n Introduce la altura:").replace(",","."))
print("\nEl área del paralelogramo es", base*altura, "unidades cuadradas." )
# Out:
# Programa para calcular el area de un paralelogramo (base x altura).
#  Introduce la base: 7.9
#
#  Introduce la altura: 7,7
# El área del paralelogramo es 60.830000000000005 unidades cuadradas.

# %% [markdown]
# ![ejercicio.png](./img/ejercicio.png)
#
# ## Ejercicio 5
# Complete el siguiente código para solicitar al usuario su nombre y su edad. Luego, calcule en qué año nació el usuario y muestre el resultado.

# %%
nombre = input("¿Cuál es tu nombre? ")
edad = int(input("¿Cuál es tu edad? "))
año_actual = 2026  # Puedes cambiarlo según el año en curso
año_nacimiento = año_actual - edad

print(f"{nombre}, naciste en el año {año_nacimiento}.")
# Out:
# ¿Cuál es tu nombre?  Tux
# ¿Cuál es tu edad?  50
# Tux, naciste en el año 1976.
