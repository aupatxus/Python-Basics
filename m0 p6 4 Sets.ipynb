# %% [markdown]
# ![TheBridge_Python_v0.png](attachment:TheBridge_Python_v0.png)

# %% [markdown]
# ## Colecciones Python: Sets

# %% [markdown]
# ### Contenidos

# %% [markdown]
# * [Introducción](#Introducción)

# %% [markdown]
# ### Introducción
# [al indice](#Contenidos)
#
# Otra colección *bulit-in* de Python, compuesta por un conjunto de *valores*. Muy parecidos a las listas. Tienen las siguientes características:
# * **Mutables**: podemos modificarlos una vez se hayan creado
# * **No ordenado**
# * **Elementos unicos**: se compone de un conjunto de valores únicas
#
# **¿Cuándo usar sets?** Cuando estemos buscando unicidad en nuestros datos y no nos importe el orden.
#
# Te dejo por aquí [la documentación](https://docs.python.org/2/library/sets.html) para realizar consultas sobre los sets
#
# Si sintaxis es:
# >```Python
# > mi_set = {elemento1, elemento2, elemento3}
# >```
#
# Tiene una sintaxis muy parecida a la de las listas, pero en este caso no se utilizan los `{}`.

# %%
https://docs.python.org/2/library/sets.html
"""
sets — Unordered collections of unique elements

 
class sets.Set([iterable])
class sets.ImmutableSet([iterable])



Set Objects


Instances of Set and ImmutableSet both provide the following operations:

len(s)   number of elements in set s (cardinality)
x in s   test x for membership in s   
x not in s   test x for non-membership in s
s.issubset(t)   s <= t   test whether every element in s is in t
s.issuperset(t)   s >= t   test whether every element in t is in s
s.union(t)   s | t   new set with elements from both s and t
s.intersection(t)   s & t   new set with elements common to s and t
s.difference(t)   s - t   new set with elements in s but not in t
s.symmetric_difference(t)   s ^ t   new set with elements in either s or t but not both
s.copy()   new set with a shallow copy of s


The following table lists operations available in ImmutableSet but not found in Set:

hash(s)   returns a hash value for s


The following table lists operations available in Set but not found in ImmutableSet:

s.update(t)   s |= t   return set s with elements added from t
s.intersection_update(t)   s &= t   return set s keeping only elements also found in t
s.difference_update(t)   s -= t   return set s after removing elements found in t
s.symmetric_difference_update(t)   s ^= t   return set s with elements from s or t but not both
s.add(x)   add element x to set s
s.remove(x)   remove x from set s; raises KeyError if not present
s.discard(x)   removes x from set s if present
s.pop()   remove and return an arbitrary element from s; raises KeyError if empty
s.clear()   remove all elements from set s
"""

# %%
colores = {"azul", "rojo", "verde", "naranja", "naranja", "naranja", "rojo", "verde",}
print(type(colores))
print(colores) #los mostrará sin orden y sin duplicados
# Out:
# <class 'set'>
# {'azul', 'naranja', 'verde', 'rojo'}

# %% [markdown]
# Los elementos del set son unicos, por lo que si en la declaración, o posteriormente añadiendo elementos hubiese algún duplicado, el set lo ignoraría. Es más, cuando aplicas el `len`, muestra la cantidad de valores únicos que tiene.

# %%
print(len(colores))
# Out:
# 4

# %%
# Añadir valores
colores.add("magenta")
print(colores)
print(len(colores))
# Out:
# {'magenta', 'verde', 'azul', 'naranja', 'rojo'}
# 5

# %%
colores.update(["celeste", "burdeos", "naranja"])
print(colores)
print(len(colores))
# Out:
# {'celeste', 'magenta', 'verde', 'azul', 'naranja', 'rojo', 'burdeos'}
# 7

# %%
# Remove

colores.remove("naranja")
print(colores)
print(len(colores))
# Out:
# {'celeste', 'magenta', 'verde', 'azul', 'rojo', 'burdeos'}
# 6

# %%
# Iterables, los podemos recorrer con un bucle

for color in colores:
    print(color)
# Out:
# celeste
# magenta
# verde
# azul
# rojo
# burdeos

# %% [markdown]
# Para comprobar si dos sets tienen los mismos elementos

# %%
# comparación == 

set1 = {1,2,4,4,2,1,2,1}
set2 = {2,1,4}

set1 == set2
print(set1)
print(set2)
# Out:
# {1, 2, 4}
# {1, 2, 4}

# %%
# quitar duplicados de las listas
lista_con = [100,10,23,23,15,32,45,10,100,23]
print(lista_con, type(lista_con))
print(set(lista_con), type(set(lista_con))) 
print(list(set(lista_con)), type(list(set(lista_con))))
# Out:
# [100, 10, 23, 23, 15, 32, 45, 10, 100, 23] <class 'list'>
# {32, 100, 10, 45, 15, 23} <class 'set'>
# [32, 100, 10, 45, 15, 23] <class 'list'>

# %%
lista_con = list(set(lista_con))
print(lista_con, type(lista_con))
# Out:
# [32, 100, 10, 45, 15, 23] <class 'list'>
