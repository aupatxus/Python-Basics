# %% [markdown]
# ![TheBridge_Python_v0.png](attachment:TheBridge_Python_v0.png)

# %% [markdown]
# ##  Colecciones Python: Tuplas

# %% [markdown]
# ### Contenidos

# %% [markdown]
# * [Introducción](#Introducción)
#
# * [Listas y tuplas](#Listas-y-tuplas)

# %% [markdown]
# ### Introducción
# [al indice](#Contenidos)
#
# Muy similares a las listas. Si en Notebooks anteriores definíamos a las listas como ordenadas y mutables, las tuplas son ordenadas e inmutables.
#
# * **Inmutables**: una vez creada la tupla con sus elementos iniciales, no se puede modificar
# * **Ordenadas**: podemos acceder a sus elementos a través del indice y reordenar la tupla según queramos
#
# Las tuplas se suelen usar para pequeñas colecciones de datos que no van a cambiar a lo largo del programa, como es el caso de las constantes.
#
# Si las listas se construían mediante corchetes `[]`, las tuplas lo hacen con los paréntesis `()`

# %%
tupla_ejemplo=(3,"texto",3.1416)
print(type(tupla_ejemplo), tupla_ejemplo)
# Out:
# <class 'tuple'> (3, 'texto', 3.1416)

# %%
print("El primer elemento de la tupla es", tupla_ejemplo[0], type(tupla_ejemplo[0]))
print("El segundo elemento de la tupla es", tupla_ejemplo[1], type(tupla_ejemplo[1]))
print("El tercer elemento de la tupla es", tupla_ejemplo[2], type(tupla_ejemplo[2]))
# Out:
# El primer elemento de la tupla es 3 <class 'int'>
# El segundo elemento de la tupla es texto <class 'str'>
# El tercer elemento de la tupla es 3.1416 <class 'float'>

# %% [markdown]
# Los paréntesis ya se usan para reordenar operaciones `5 * (3 + 4)`, por lo que hay que añadir una coma cuando definamos una tupla con un único elemento, sino Python lo interpretará como un número.

# %%
mala_tupla=(24)
print(type(mala_tupla), mala_tupla)
# Out:
# <class 'int'> 24

# %%
buena_tupla=(24,)
print(type(buena_tupla), buena_tupla)
# Out:
# <class 'tuple'> (24,)

# %%
# ANIDACIÓN TUPLA
tupla_anidada=(1,2,3,("A", "B", "C"))
print(tupla_anidada)
print(len(tupla_anidada) ,"elementos")
# Out:
# (1, 2, 3, ('A', 'B', 'C'))
# 4 elementos

# %%
print(tupla_anidada[2])
print(tupla_anidada[3][1]) #en la cuarta posición el Elemento 2
# Out:
# 3
# B

# %%
# SON ITERABLES
for i in tupla_anidada:
    print(i)
# Out:
# 1
# 2
# 3
# ('A', 'B', 'C')

# %%
# Ventanas o Slicing con tuplas

tupla_bis = tupla_anidada[2:] # desde el tercer elemento hasta el final
print(tupla_bis)
# Out:
# (3, ('A', 'B', 'C'))

# %% [markdown]
# <table align="left">
#  <tr>
#      <td style="text-align:left">
#          <h3>ERRORES tuplas</h3>
#
#  </td></tr>
# </table>

# %% [markdown]
# Cuidado que las tuplas son inmutables, y una vez creadas no las podrás modificar después

# %%
tupla_error = (1,2,3,4,5)
tupla_error[3] = 23 # ni append ni pop, tampoco podremos
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 tupla_error = (1,2,3,4,5)
# ----> 2 tupla_error[3] = 23
#
# TypeError: 'tuple' object does not support item assignment

# %%
# Si queremos añadir elementos, podemos meterlos en otra tupla y sumarlas para que se concatenen

# %%
tupla_1 = (1,2,3)
tupla_2 = (4,5,6)
print(tupla_1)

print(tupla_1 + tupla_2)

tupla_3 = tupla_1 + tupla_2
print(tupla_3)
tupla_1 = tupla_1 + tupla_2 #reasignación
print(tupla_1)
# Out:
# (1, 2, 3)
# (1, 2, 3, 4, 5, 6)
# (1, 2, 3, 4, 5, 6)
# (1, 2, 3, 4, 5, 6)

# %% [markdown]
# ### Listas y tuplas
# [al indice](#Contenidos)
#
# Podemos combinar listas y tuplas que no tendremos ningún problema, siempre y cuando respetemos las propiedades de cada tipo de dato.

# %%
lista_ejemplo = ["Fresas", ("Naranjas", "Limones"), "Kiwis"] #mutable, permitirá modificar elementos y añadir salvo dentro de la tupla
tupla_lista = ("Fresas", ["Naranjas", "Limones"], "Kiwis") #no vamos a poder modificar nada

print(lista_ejemplo, type(lista_ejemplo))
print(tupla_lista, type(tupla_lista))
# Out:
# ['Fresas', ('Naranjas', 'Limones'), 'Kiwis'] <class 'list'>
# ('Fresas', ['Naranjas', 'Limones'], 'Kiwis') <class 'tuple'>
